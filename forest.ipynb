# %% [markdown]
# <a href="https://colab.research.google.com/github/shitzkhn/Severity-Model/blob/master/forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
sample=pd.read_csv('sample_submission.csv')

# %%
sample.head()
# Out:
#    Accident_ID                                 Severity
# 0            1                Minor_Damage_And_Injuries
# 1           10                Highly_Fatal_And_Damaging
# 2           14                Highly_Fatal_And_Damaging
# 3           17  Significant_Damage_And_Serious_Injuries
# 4           21                Minor_Damage_And_Injuries

# %%
dict={'Minor_Damage_And_Injuries':1,'Significant_Damage_And_Serious_Injuries':2,'Significant_Damage_And_Fatalities':3,'Highly_Fatal_And_Damaging':4}

# %%
df
# Out:
#                                      Severity  ...  Accident_ID
# 0                   Minor_Damage_And_Injuries  ...         7570
# 1                   Minor_Damage_And_Injuries  ...        12128
# 2           Significant_Damage_And_Fatalities  ...         2181
# 3     Significant_Damage_And_Serious_Injuries  ...         5946
# 4           Significant_Damage_And_Fatalities  ...         9054
# ...                                       ...  ...          ...
# 9995  Significant_Damage_And_Serious_Injuries  ...        11493
# 9996                Highly_Fatal_And_Damaging  ...          305
# 9997  Significant_Damage_And_Serious_Injuries  ...          612
# 9998                Minor_Damage_And_Injuries  ...         4963
# 9999                Highly_Fatal_And_Damaging  ...         9387
#
# [10000 rows x 12 columns]

# %%
for i in range(0,10000):
  df.iloc[i,0]=dict[df.iloc[i,0]]

# %%
df
# Out:
#       Severity  Safety_Score  ...  Adverse_Weather_Metric  Accident_ID
# 0            1     49.223744  ...                0.424352         7570
# 1            1     62.465753  ...                0.352350        12128
# 2            3     63.059361  ...                0.003364         2181
# 3            2     48.082192  ...                0.211728         5946
# 4            3     26.484018  ...                0.176883         9054
# ...        ...           ...  ...                     ...          ...
# 9995         2     56.118721  ...                0.026150        11493
# 9996         4     40.365297  ...                0.074898          305
# 9997         2     27.853881  ...                0.168173          612
# 9998         1     56.210046  ...                0.026381         4963
# 9999         4     50.000000  ...                0.017036         9387
#
# [10000 rows x 12 columns]

# %%
import numpy as np

# %%
target=np.array(df['Severity'])
df=df.drop('Severity',axis=1)
features=list(df.columns)
df=np.array(df)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
m = RandomForestRegressor(n_estimators=40,max_features=0.8,n_jobs=-1, oob_score=True)
m.fit(df, target)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=0.8, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=40, n_jobs=-1, oob_score=True,
#                       random_state=None, verbose=0, warm_start=False)

# %%
test=pd.read_csv("test.csv")
test
# Out:
#       Safety_Score  Days_Since_Inspection  ...  Adverse_Weather_Metric  Accident_ID
# 0        19.497717                     16  ...                0.069692            1
# 1        58.173516                     15  ...                0.002777           10
# 2        33.287671                     15  ...                0.004316           14
# 3         3.287671                     21  ...                0.199990           17
# 4        10.867580                     18  ...                0.483696           21
# ...            ...                    ...  ...                     ...          ...
# 2495     68.127854                      8  ...                0.659387        12484
# 2496     54.840183                      9  ...                0.005010        12487
# 2497     36.712329                     14  ...                0.008629        12488
# 2498     38.721461                     13  ...                0.006247        12491
# 2499     36.073059                     11  ...                0.024409        12493
#
# [2500 rows x 11 columns]

# %%
predictions=m.predict(test)
predictions
# Out:
# array([4.   , 3.   , 2.   , ..., 1.975, 2.   , 4.   ])

# %%
preds = np.stack([t.predict(test) for t in m.estimators_])
preds.shape
predictions=[]

# %%
for i in range(0,2500):
  predictions.append(np.mean(preds[:,i]))

predictions
# Out:
# [4.0,
#  3.0,
#  2.0,
#  3.5,
#  3.325,
#  2.95,
#  2.95,
#  4.0,
#  3.9,
#  2.05,
#  2.25,
#  2.05,
#  3.75,
#  2.575,
#  2.725,
#  2.1,
#  4.0,
#  3.175,
#  2.6,
#  3.175,
#  3.95,
#  2.0,
#  3.025,
#  2.775,
#  4.0,
#  2.475,
#  3.175,
#  4.0,
#  3.075,
#  2.175,
#  1.75,
#  2.375,
#  1.6,
#  4.0,
#  3.65,
#  1.25,
#  4.0,
#  1.7,
#  3.95,
#  2.25,
#  1.275,
#  2.0,
#  3.0,
#  3.1,
#  2.3,
#  4.0,
#  1.325,
#  1.025,
#  4.0,
#  2.0,
#  1.075,
#  2.8,
#  2.825,
#  4.0,
#  3.475,
#  1.2,
#  4.0,
#  1.075,
#  3.175,
#  3.825,
#  1.2,
#  1.6,
#  3.2,
#  3.525,
#  2.0,
#  2.0,
#  4.0,
#  2.65,
#  2.075,
#  1.025,
#  3.95,
#  4.0,
#  4.0,
#  2.975,
#  4.0,
#  4.0,
#  1.425,
#  2.975,
#  1.15,
#  3.95,
#  3.95,
#  2.175,
#  3.875,
#  1.7,
#  1.375,
#  4.0,
#  2.9,
#  2.675,
#  3.725,
#  1.9,
#  1.025,
#  2.0,
#  1.875,
#  1.025,
#  1.4,
#  2.975,
#  3.5,
#  1.975,
#  3.95,
#  2.0,
#  2.925,
#  1.5,
#  4.0,
#  1.4,
#  4.0,
#  1.725,
#  1.025,
#  1.975,
#  3.0,
#  1.675,
#  2.0,
#  1.425,
#  4.0,
#  1.0,
#  4.0,
#  1.8,
#  3.0,
#  4.0,
#  3.95,
#  2.2,
#  1.9,
#  1.075,
#  2.0,
#  4.0,
#  2.75,
#  4.0,
#  1.175,
#  2.4,
#  2.0,
#  1.125,
#  3.95,
#  1.975,
#  1.95,
#  4.0,
#  4.0,
#  2.0,
#  1.175,
#  2.0,
#  2.05,
#  2.0,
#  1.4,
#  3.125,
#  3.075,
#  1.45,
#  4.0,
#  1.075,
#  2.025,
#  2.1,
#  3.4,
#  2.825,
#  1.175,
#  1.1,
#  2.725,
#  2.05,
#  2.0,
#  2.0,
#  4.0,
#  1.975,
#  2.25,
#  1.0,
#  2.975,
#  4.0,
#  2.95,
#  1.0,
#  3.2,
#  1.175,
#  2.0,
#  3.4,
#  4.0,
#  1.775,
#  2.0,
#  1.15,
#  2.125,
#  2.15,
#  1.8,
#  3.2,
#  3.95,
#  1.275,
#  1.45,
#  3.925,
#  3.8,
#  1.35,
#  4.0,
#  2.0,
#  1.05,
#  3.85,
#  3.075,
#  3.95,
#  3.95,
#  2.4,
#  2.05,
#  1.175,
#  2.8,
#  3.0,
#  4.0,
#  3.975,
#  2.975,
#  2.225,
#  1.25,
#  1.075,
#  1.325,
#  1.925,
#  1.15,
#  1.35,
#  1.475,
#  3.95,
#  2.85,
#  2.15,
#  1.0,
#  4.0,
#  2.95,
#  3.95,
#  1.075,
#  4.0,
#  2.6,
#  3.925,
#  2.0,
#  1.775,
#  2.75,
#  2.975,
#  3.25,
#  1.1,
#  1.1,
#  4.0,
#  2.0,
#  1.975,
#  1.175,
#  3.525,
#  2.35,
#  4.0,
#  2.5,
#  1.575,
#  3.875,
#  2.0,
#  3.95,
#  1.975,
#  3.625,
#  2.025,
#  4.0,
#  2.975,
#  2.95,
#  1.1,
#  3.95,
#  2.0,
#  3.95,
#  1.975,
#  2.0,
#  1.425,
#  3.1,
#  3.975,
#  1.275,
#  2.175,
#  2.95,
#  1.0,
#  2.025,
#  2.0,
#  1.975,
#  4.0,
#  2.0,
#  1.95,
#  1.0,
#  1.025,
#  1.95,
#  2.775,
#  1.025,
#  2.2,
#  3.925,
#  3.0,
#  2.35,
#  1.125,
#  1.25,
#  2.25,
#  1.25,
#  1.975,
#  1.2,
#  4.0,
#  3.275,
#  1.25,
#  2.7,
#  1.025,
#  3.9,
#  1.0,
#  1.1,
#  1.175,
#  1.075,
#  3.0,
#  1.4,
#  1.2,
#  3.35,
#  1.225,
#  1.075,
#  1.05,
#  4.0,
#  1.175,
#  3.95,
#  1.975,
#  1.0,
#  1.775,
#  1.1,
#  4.0,
#  2.025,
#  4.0,
#  1.975,
#  1.05,
#  2.85,
#  2.95,
#  1.875,
#  3.625,
#  2.0,
#  2.0,
#  4.0,
#  4.0,
#  4.0,
#  1.05,
#  3.875,
#  3.95,
#  3.0,
#  3.825,
#  1.15,
#  2.0,
#  1.1,
#  4.0,
#  4.0,
#  3.8,
#  4.0,
#  2.0,
#  1.4,
#  3.0,
#  3.0,
#  2.75,
#  1.975,
#  4.0,
#  3.9,
#  2.0,
#  1.975,
#  1.55,
#  4.0,
#  3.0,
#  3.275,
#  1.125,
#  1.35,
#  1.075,
#  4.0,
#  2.0,
#  4.0,
#  3.075,
#  1.0,
#  1.25,
#  1.925,
#  1.85,
#  4.0,
#  2.825,
#  2.6,
#  1.275,
#  1.125,
#  1.875,
#  1.35,
#  4.0,
#  4.0,
#  1.125,
#  2.95,
#  3.0,
#  2.0,
#  2.2,
#  1.075,
#  2.875,
#  2.85,
#  1.1,
#  1.95,
#  2.0,
#  1.05,
#  2.95,
#  2.85,
#  1.85,
#  1.25,
#  2.575,
#  3.25,
#  3.95,
#  1.875,
#  1.1,
#  4.0,
#  3.0,
#  1.175,
#  1.025,
#  3.225,
#  2.8,
#  3.0,
#  2.225,
#  1.125,
#  1.425,
#  1.175,
#  1.05,
#  1.175,
#  4.0,
#  3.475,
#  3.0,
#  3.0,
#  4.0,
#  1.15,
#  2.0,
#  4.0,
#  4.0,
#  1.025,
#  2.0,
#  1.25,
#  2.0,
#  3.175,
#  1.025,
#  2.0,
#  1.05,
#  2.0,
#  1.45,
#  3.125,
#  3.35,
#  3.95,
#  2.2,
#  1.25,
#  3.95,
#  2.325,
#  2.825,
#  3.175,
#  4.0,
#  2.0,
#  1.175,
#  3.125,
#  2.0,
#  1.075,
#  2.775,
#  1.325,
#  3.65,
#  2.9,
#  1.075,
#  3.1,
#  2.0,
#  4.0,
#  1.875,
#  2.0,
#  3.0,
#  3.0,
#  2.0,
#  3.0,
#  2.025,
#  3.5,
#  4.0,
#  3.1,
#  1.2,
#  1.625,
#  4.0,
#  3.025,
#  1.05,
#  3.0,
#  2.1,
#  3.825,
#  1.9,
#  1.4,
#  1.275,
#  3.475,
#  4.0,
#  4.0,
#  1.975,
#  1.125,
#  2.025,
#  2.75,
#  2.65,
#  1.05,
#  3.25,
#  4.0,
#  4.0,
#  4.0,
#  2.325,
#  1.975,
#  2.0,
#  2.0,
#  2.275,
#  4.0,
#  3.025,
#  3.65,
#  1.325,
#  4.0,
#  2.925,
#  2.0,
#  3.0,
#  1.025,
#  3.15,
#  4.0,
#  1.95,
#  2.2,
#  3.175,
#  3.975,
#  4.0,
#  3.05,
#  2.15,
#  4.0,
#  3.95,
#  4.0,
#  1.875,
#  3.95,
#  2.8,
#  1.975,
#  2.0,
#  2.05,
#  4.0,
#  1.975,
#  2.1,
#  2.925,
#  4.0,
#  3.95,
#  3.95,
#  2.05,
#  1.05,
#  2.0,
#  1.025,
#  3.425,
#  1.475,
#  1.075,
#  1.825,
#  1.1,
#  1.025,
#  3.7,
#  3.6,
#  3.175,
#  4.0,
#  2.05,
#  3.0,
#  1.325,
#  4.0,
#  2.75,
#  1.275,
#  1.075,
#  1.35,
#  1.0,
#  1.075,
#  1.35,
#  1.4,
#  2.0,
#  1.55,
#  4.0,
#  1.05,
#  2.925,
#  4.0,
#  4.0,
#  1.95,
#  3.9,
#  2.95,
#  2.775,
#  2.075,
#  4.0,
#  2.025,
#  1.05,
#  1.15,
#  2.0,
#  3.95,
#  4.0,
#  3.325,
#  3.0,
#  1.0,
#  1.7,
#  3.575,
#  3.95,
#  2.0,
#  1.075,
#  1.925,
#  4.0,
#  1.525,
#  3.95,
#  2.1,
#  3.375,
#  3.475,
#  3.0,
#  2.0,
#  3.025,
#  2.95,
#  4.0,
#  2.9,
#  2.0,
#  1.475,
#  2.3,
#  2.0,
#  4.0,
#  4.0,
#  1.85,
#  1.225,
#  1.825,
#  4.0,
#  3.525,
#  3.675,
#  2.025,
#  4.0,
#  3.925,
#  3.95,
#  2.0,
#  1.05,
#  2.175,
#  1.825,
#  1.95,
#  1.375,
#  1.125,
#  1.0,
#  4.0,
#  3.0,
#  2.15,
#  2.0,
#  2.275,
#  2.0,
#  1.275,
#  2.0,
#  3.175,
#  2.0,
#  1.925,
#  1.95,
#  3.65,
#  3.025,
#  1.0,
#  1.175,
#  4.0,
#  2.4,
#  1.325,
#  4.0,
#  2.125,
#  3.95,
#  2.05,
#  2.975,
#  4.0,
#  4.0,
#  1.05,
#  1.225,
#  2.9,
#  4.0,
#  1.1,
#  2.0,
#  2.0,
#  3.05,
#  1.025,
#  3.95,
#  1.075,
#  1.325,
#  3.125,
#  3.9,
#  1.125,
#  3.275,
#  1.0,
#  1.375,
#  2.85,
#  2.9,
#  1.975,
#  1.2,
#  4.0,
#  3.95,
#  2.575,
#  3.675,
#  2.0,
#  2.225,
#  1.1,
#  2.95,
#  3.9,
#  1.075,
#  3.075,
#  4.0,
#  3.75,
#  1.025,
#  1.175,
#  1.175,
#  2.05,
#  1.025,
#  3.5,
#  4.0,
#  2.1,
#  3.0,
#  4.0,
#  2.75,
#  2.0,
#  2.95,
#  2.0,
#  2.0,
#  3.15,
#  2.0,
#  1.0,
#  1.0,
#  3.05,
#  4.0,
#  2.0,
#  1.375,
#  1.475,
#  1.225,
#  1.075,
#  1.3,
#  3.925,
#  2.95,
#  1.425,
#  1.725,
#  1.975,
#  1.95,
#  2.6,
#  1.025,
#  2.875,
#  2.025,
#  3.025,
#  1.0,
#  1.625,
#  2.0,
#  3.8,
#  2.85,
#  2.1,
#  2.75,
#  3.025,
#  1.95,
#  2.75,
#  2.0,
#  2.0,
#  2.0,
#  3.625,
#  1.625,
#  1.125,
#  2.0,
#  1.875,
#  1.175,
#  1.975,
#  1.975,
#  1.075,
#  3.025,
#  2.525,
#  4.0,
#  3.3,
#  4.0,
#  1.0,
#  2.9,
#  1.05,
#  3.0,
#  2.025,
#  2.0,
#  1.125,
#  3.35,
#  4.0,
#  1.2,
#  1.3,
#  2.0,
#  2.95,
#  2.975,
#  3.1,
#  1.45,
#  1.125,
#  2.525,
#  3.0,
#  2.0,
#  4.0,
#  4.0,
#  3.1,
#  1.975,
#  3.1,
#  2.0,
#  3.9,
#  4.0,
#  1.0,
#  3.8,
#  3.0,
#  3.1,
#  4.0,
#  2.0,
#  1.05,
#  2.0,
#  1.975,
#  3.0,
#  2.05,
#  1.85,
#  1.0,
#  3.95,
#  1.45,
#  4.0,
#  4.0,
#  4.0,
#  2.125,
#  1.25,
#  2.075,
#  1.725,
#  4.0,
#  3.35,
#  3.325,
#  2.0,
#  1.375,
#  2.6,
#  1.65,
#  2.0,
#  1.15,
#  3.425,
#  4.0,
#  1.025,
#  1.975,
#  2.0,
#  2.0,
#  3.0,
#  4.0,
#  3.0,
#  1.725,
#  2.05,
#  4.0,
#  2.0,
#  1.0,
#  4.0,
#  1.275,
#  3.125,
#  4.0,
#  1.375,
#  2.0,
#  2.0,
#  2.825,
#  2.95,
#  1.0,
#  3.65,
#  1.225,
#  2.0,
#  1.55,
#  1.0,
#  1.6,
#  3.65,
#  4.0,
#  2.05,
#  2.0,
#  3.75,
#  3.825,
#  4.0,
#  3.2,
#  3.05,
#  1.95,
#  4.0,
#  3.75,
#  4.0,
#  3.4,
#  3.925,
#  1.5,
#  4.0,
#  4.0,
#  2.6,
#  2.0,
#  4.0,
#  4.0,
#  2.075,
#  1.2,
#  2.15,
#  1.05,
#  2.0,
#  4.0,
#  1.45,
#  1.05,
#  4.0,
#  1.0,
#  2.0,
#  2.05,
#  2.0,
#  3.95,
#  4.0,
#  4.0,
#  2.725,
#  4.0,
#  3.975,
#  1.075,
#  2.1,
#  4.0,
#  3.9,
#  1.275,
#  3.1,
#  2.05,
#  2.875,
#  3.0,
#  3.225,
#  3.0,
#  2.0,
#  4.0,
#  1.075,
#  4.0,
#  1.975,
#  1.75,
#  4.0,
#  3.0,
#  4.0,
#  1.0,
#  2.875,
#  2.325,
#  3.9,
#  4.0,
#  4.0,
#  4.0,
#  1.0,
#  3.775,
#  2.0,
#  2.95,
#  2.0,
#  2.0,
#  2.0,
#  1.25,
#  4.0,
#  1.05,
#  2.05,
#  1.775,
#  3.725,
#  1.95,
#  4.0,
#  3.0,
#  2.075,
#  4.0,
#  4.0,
#  2.975,
#  1.425,
#  2.95,
#  1.25,
#  2.85,
#  1.125,
#  1.925,
#  1.1,
#  2.0,
#  1.05,
#  3.95,
#  1.0,
#  1.0,
#  2.0,
#  2.025,
#  2.0,
#  3.95,
#  1.1,
#  2.0,
#  2.75,
#  1.875,
#  1.225,
#  2.8,
#  2.0,
#  1.65,
#  3.95,
#  4.0,
#  1.225,
#  1.275,
#  4.0,
#  2.0,
#  4.0,
#  1.1,
#  1.0,
#  1.775,
#  1.25,
#  2.0,
#  3.0,
#  1.35,
#  2.0,
#  3.975,
#  1.6,
#  3.0,
#  3.65,
#  2.425,
#  2.0,
#  1.0,
#  2.0,
#  2.1,
#  1.05,
#  1.975,
#  2.875,
#  4.0,
#  3.025,
#  4.0,
#  1.325,
#  4.0,
#  2.9,
#  2.225,
#  2.325,
#  3.05,
#  3.95,
#  4.0,
#  4.0,
#  3.075,
#  1.05,
#  1.05,
#  3.85,
#  2.975,
#  1.9,
#  4.0,
#  3.225,
#  1.225,
#  1.2,
#  3.275,
#  1.075,
#  2.95,
#  1.95,
#  2.95,
#  1.0,
#  4.0,
#  1.025,
#  3.95,
#  3.15,
#  2.8,
#  2.05,
#  4.0,
#  4.0,
#  4.0,
#  3.95,
#  2.1,
#  4.0,
#  3.8,
#  1.35,
#  3.0,
#  3.0,
#  2.0,
#  4.0,
#  2.0,
#  1.9,
#  ...]

# %%
for i in range(0,2500):
  c=predictions[i]
  a=int(c)
  if(c-a>0.5):
    predictions[i]=a+1
  else:
    predictions[i]=a
  
predictions
# Out:
# [4,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  2,
#  2,
#  2,
#  4,
#  3,
#  3,
#  2,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  4,
#  2,
#  3,
#  4,
#  3,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  4,
#  2,
#  4,
#  2,
#  1,
#  2,
#  3,
#  3,
#  2,
#  4,
#  1,
#  1,
#  4,
#  2,
#  1,
#  3,
#  3,
#  4,
#  3,
#  1,
#  4,
#  1,
#  3,
#  4,
#  1,
#  2,
#  3,
#  4,
#  2,
#  2,
#  4,
#  3,
#  2,
#  1,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  1,
#  3,
#  1,
#  4,
#  4,
#  2,
#  4,
#  2,
#  1,
#  4,
#  3,
#  3,
#  4,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  3,
#  3,
#  2,
#  4,
#  2,
#  3,
#  1,
#  4,
#  1,
#  4,
#  2,
#  1,
#  2,
#  3,
#  2,
#  2,
#  1,
#  4,
#  1,
#  4,
#  2,
#  3,
#  4,
#  4,
#  2,
#  2,
#  1,
#  2,
#  4,
#  3,
#  4,
#  1,
#  2,
#  2,
#  1,
#  4,
#  2,
#  2,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  2,
#  2,
#  3,
#  3,
#  1,
#  1,
#  3,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  3,
#  4,
#  3,
#  1,
#  3,
#  1,
#  2,
#  3,
#  4,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  3,
#  4,
#  1,
#  1,
#  4,
#  4,
#  1,
#  4,
#  2,
#  1,
#  4,
#  3,
#  4,
#  4,
#  2,
#  2,
#  1,
#  3,
#  3,
#  4,
#  4,
#  3,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  4,
#  3,
#  2,
#  1,
#  4,
#  3,
#  4,
#  1,
#  4,
#  3,
#  4,
#  2,
#  2,
#  3,
#  3,
#  3,
#  1,
#  1,
#  4,
#  2,
#  2,
#  1,
#  4,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  3,
#  3,
#  1,
#  4,
#  2,
#  4,
#  2,
#  2,
#  1,
#  3,
#  4,
#  1,
#  2,
#  3,
#  1,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  1,
#  1,
#  2,
#  3,
#  1,
#  2,
#  4,
#  3,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  4,
#  3,
#  1,
#  3,
#  1,
#  4,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  4,
#  1,
#  4,
#  2,
#  1,
#  2,
#  1,
#  4,
#  2,
#  4,
#  2,
#  1,
#  3,
#  3,
#  2,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  1,
#  4,
#  4,
#  3,
#  4,
#  1,
#  2,
#  1,
#  4,
#  4,
#  4,
#  4,
#  2,
#  1,
#  3,
#  3,
#  3,
#  2,
#  4,
#  4,
#  2,
#  2,
#  2,
#  4,
#  3,
#  3,
#  1,
#  1,
#  1,
#  4,
#  2,
#  4,
#  3,
#  1,
#  1,
#  2,
#  2,
#  4,
#  3,
#  3,
#  1,
#  1,
#  2,
#  1,
#  4,
#  4,
#  1,
#  3,
#  3,
#  2,
#  2,
#  1,
#  3,
#  3,
#  1,
#  2,
#  2,
#  1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  4,
#  2,
#  1,
#  4,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  3,
#  3,
#  3,
#  4,
#  1,
#  2,
#  4,
#  4,
#  1,
#  2,
#  1,
#  2,
#  3,
#  1,
#  2,
#  1,
#  2,
#  1,
#  3,
#  3,
#  4,
#  2,
#  1,
#  4,
#  2,
#  3,
#  3,
#  4,
#  2,
#  1,
#  3,
#  2,
#  1,
#  3,
#  1,
#  4,
#  3,
#  1,
#  3,
#  2,
#  4,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  4,
#  3,
#  1,
#  2,
#  4,
#  3,
#  1,
#  3,
#  2,
#  4,
#  2,
#  1,
#  1,
#  3,
#  4,
#  4,
#  2,
#  1,
#  2,
#  3,
#  3,
#  1,
#  3,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  3,
#  4,
#  1,
#  4,
#  3,
#  2,
#  3,
#  1,
#  3,
#  4,
#  2,
#  2,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  3,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  3,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  1,
#  3,
#  1,
#  1,
#  2,
#  1,
#  1,
#  4,
#  4,
#  3,
#  4,
#  2,
#  3,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  4,
#  1,
#  3,
#  4,
#  4,
#  2,
#  4,
#  3,
#  3,
#  2,
#  4,
#  2,
#  1,
#  1,
#  2,
#  4,
#  4,
#  3,
#  3,
#  1,
#  2,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  2,
#  4,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  4,
#  3,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  4,
#  3,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  2,
#  2,
#  4,
#  3,
#  1,
#  1,
#  4,
#  2,
#  1,
#  4,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  1,
#  1,
#  3,
#  4,
#  1,
#  2,
#  2,
#  3,
#  1,
#  4,
#  1,
#  1,
#  3,
#  4,
#  1,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  4,
#  3,
#  4,
#  2,
#  2,
#  1,
#  3,
#  4,
#  1,
#  3,
#  4,
#  4,
#  1,
#  1,
#  1,
#  2,
#  1,
#  3,
#  4,
#  2,
#  3,
#  4,
#  3,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  4,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  3,
#  1,
#  2,
#  2,
#  2,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  2,
#  2,
#  4,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  1,
#  2,
#  2,
#  1,
#  3,
#  3,
#  4,
#  3,
#  4,
#  1,
#  3,
#  1,
#  3,
#  2,
#  2,
#  1,
#  3,
#  4,
#  1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  4,
#  4,
#  3,
#  2,
#  3,
#  2,
#  4,
#  4,
#  1,
#  4,
#  3,
#  3,
#  4,
#  2,
#  1,
#  2,
#  2,
#  3,
#  2,
#  2,
#  1,
#  4,
#  1,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  4,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  1,
#  3,
#  4,
#  1,
#  2,
#  2,
#  2,
#  3,
#  4,
#  3,
#  2,
#  2,
#  4,
#  2,
#  1,
#  4,
#  1,
#  3,
#  4,
#  1,
#  2,
#  2,
#  3,
#  3,
#  1,
#  4,
#  1,
#  2,
#  2,
#  1,
#  2,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  3,
#  3,
#  2,
#  4,
#  4,
#  4,
#  3,
#  4,
#  1,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  2,
#  1,
#  2,
#  1,
#  2,
#  4,
#  1,
#  1,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  1,
#  2,
#  4,
#  4,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  4,
#  1,
#  4,
#  2,
#  2,
#  4,
#  3,
#  4,
#  1,
#  3,
#  2,
#  4,
#  4,
#  4,
#  4,
#  1,
#  4,
#  2,
#  3,
#  2,
#  2,
#  2,
#  1,
#  4,
#  1,
#  2,
#  2,
#  4,
#  2,
#  4,
#  3,
#  2,
#  4,
#  4,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  1,
#  2,
#  1,
#  4,
#  1,
#  1,
#  2,
#  2,
#  2,
#  4,
#  1,
#  2,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  4,
#  4,
#  1,
#  1,
#  4,
#  2,
#  4,
#  1,
#  1,
#  2,
#  1,
#  2,
#  3,
#  1,
#  2,
#  4,
#  2,
#  3,
#  4,
#  2,
#  2,
#  1,
#  2,
#  2,
#  1,
#  2,
#  3,
#  4,
#  3,
#  4,
#  1,
#  4,
#  3,
#  2,
#  2,
#  3,
#  4,
#  4,
#  4,
#  3,
#  1,
#  1,
#  4,
#  3,
#  2,
#  4,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  4,
#  1,
#  4,
#  3,
#  3,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  1,
#  3,
#  3,
#  2,
#  4,
#  2,
#  2,
#  ...]

# %%
dict={1:'Minor_Damage_And_Injuries',2:'Significant_Damage_And_Serious_Injuries',3:'Significant_Damage_And_Fatalities',4:'Highly_Fatal_And_Damaging'}

# %%
data_pred=[]
for i in range(0,2500):
  data_pred.append(dict[predictions[i]])

data_pred
# Out:
# ['Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Highly_Fatal_And_Damaging',
#  'Minor_Damage_And_Injuries',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Fatalities',
#  'Significant_Damage_And_Serious_Injuries',
#  'Highly_Fatal_And_Damaging',
#  'Significant_Damage_And_Serious_Injuries',
#  'Significant_Damage_And_Serious_Injuries',
#  ...]

# %%
ids=pd.Series(test.iloc[:,10])
ids
# Out:
# 0           1
# 1          10
# 2          14
# 3          17
# 4          21
#         ...
# 2495    12484
# 2496    12487
# 2497    12488
# 2498    12491
# 2499    12493
# Name: Accident_ID, Length: 2500, dtype: int64

# %%
pred=pd.Series(data_pred)
pred
# Out:
# 0                     Highly_Fatal_And_Damaging
# 1             Significant_Damage_And_Fatalities
# 2       Significant_Damage_And_Serious_Injuries
# 3             Significant_Damage_And_Fatalities
# 4             Significant_Damage_And_Fatalities
#                          ...
# 2495          Significant_Damage_And_Fatalities
# 2496    Significant_Damage_And_Serious_Injuries
# 2497    Significant_Damage_And_Serious_Injuries
# 2498    Significant_Damage_And_Serious_Injuries
# 2499                  Highly_Fatal_And_Damaging
# Length: 2500, dtype: object

# %%
output= pd.DataFrame({ 'Accident_ID':ids, 'Severity':pred })

# %%
output.head()
# Out:
#    Accident_ID                                 Severity
# 0            1                Highly_Fatal_And_Damaging
# 1           10        Significant_Damage_And_Fatalities
# 2           14  Significant_Damage_And_Serious_Injuries
# 3           17        Significant_Damage_And_Fatalities
# 4           21        Significant_Damage_And_Fatalities

# %%
output.to_csv('done.csv')
from google.colab import files

files.download('done.csv')
